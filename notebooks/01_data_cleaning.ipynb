# %%
# Import Libraries


import pandas as pd               # for loading and manipulating data
import numpy as np                # for numerical operations
import matplotlib.pyplot as plt   # for plotting
import os                         # for file path handling

# This makes sure our charts appear inside the notebook
# %matplotlib inline

print(" libraries imported successfully!")
# Out:
#  libraries imported successfully!

# %%
#  Load All Datasets

# Define the path to our data folder

DATA_PATH = "../data/"

# Load all CSV files into pandas DataFrames
# A DataFrame is like an Excel spreadsheet inside Python

carbon_prices   = pd.read_csv(DATA_PATH + "carbon_prices_daily.csv")
climate_events  = pd.read_csv(DATA_PATH + "climate_events.csv")
co2_emissions   = pd.read_csv(DATA_PATH + "co2_emissions_yearly.csv")
energy_mix      = pd.read_csv(DATA_PATH + "energy_mix_yearly.csv")
temp_anomaly    = pd.read_csv(DATA_PATH + "temperature_anomaly_monthly.csv")

print(" All datasets loaded successfully!")
print(f"   carbon_prices  : {carbon_prices.shape[0]:,} rows, {carbon_prices.shape[1]} columns")
print(f"   climate_events : {climate_events.shape[0]:,} rows, {climate_events.shape[1]} columns")
print(f"   co2_emissions  : {co2_emissions.shape[0]:,} rows, {co2_emissions.shape[1]} columns")
print(f"   energy_mix     : {energy_mix.shape[0]:,} rows, {energy_mix.shape[1]} columns")
print(f"   temp_anomaly   : {temp_anomaly.shape[0]:,} rows, {temp_anomaly.shape[1]} columns")
# Out:
#  All datasets loaded successfully!
#    carbon_prices  : 15,866 rows, 5 columns
#    climate_events : 50 rows, 11 columns
#    co2_emissions  : 1,350 rows, 8 columns
#    energy_mix     : 1,350 rows, 14 columns
#    temp_anomaly   : 2,528 rows, 7 columns

# %%
# Explore CO2 Emissions


print("=" * 50)
print("CO2 EMISSIONS DATASET")
print("=" * 50)

print("\n--- First 5 rows ---")
print(co2_emissions.head())

print("\n--- Column Info ---")
print(co2_emissions.info())

print("\n--- Countries in dataset ---")
print(co2_emissions["country"].unique())

print("\n--- Year range ---")
print(f"From {co2_emissions['year'].min()} to {co2_emissions['year'].max()}")
# Out:
# ==================================================
# CO2 EMISSIONS DATASET
# ==================================================
#
# --- First 5 rows ---
#    year country iso3 region  co2_emissions_mt  population_millions  \
# 0  2000   China  CHN   Asia            3535.5               1198.5
# 1  2001   China  CHN   Asia            4049.2               1207.9
# 2  2002   China  CHN   Asia            4601.0               1217.4
# 3  2003   China  CHN   Asia            5121.6               1226.8
# 4  2004   China  CHN   Asia            5553.3               1236.3
#
#    co2_per_capita_t  co2_intensity_kg_per_gdp_usd
# 0              2.95                          0.59
# 1              3.35                          0.61
# 2              3.78                          0.63
# 3              4.17                          0.64
# 4              4.49                          0.64
#
# --- Column Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          1350 non-null   int64
#  1   country                       1350 non-null   str
#  2   iso3                          1350 non-null   str
#  3   region                        1350 non-null   str
#  4   co2_emissions_mt              1350 non-null   float64
#  5   population_millions           1350 non-null   float64
#  6   co2_per_capita_t              1350 non-null   float64
#  7   co2_intensity_kg_per_gdp_usd  1350 non-null   float64
# dtypes: float64(4), int64(1), str(3)
# memory usage: 84.5 KB
# None
#
# --- Countries in dataset ---
# <StringArray>
# [         'China',  'United States',          'India',         'Russia',
#           'Japan',        'Germany',           'Iran',    'South Korea',
#       'Indonesia',   'Saudi Arabia',         'Canada',         'Mexico',
#          'Brazil',   'South Africa',         'Turkey',      'Australia',
#  'United Kingdom',         'France',          'Italy',          'Spain',
#          'Poland',    'Netherlands',        'Ukraine', 'Czech Republic',
#         'Belgium',         'Sweden',         'Norway',        'Finland',
#         'Denmark',            'UAE',          'Egypt',           'Iraq',
#           'Qatar',         'Kuwait',        'Algeria',         'Israel',
#         'Vietnam',       'Thailand',       'Pakistan',       'Malaysia',
#     'Philippines',     'Bangladesh',     'Kazakhstan',      'Argentina',
#        'Colombia',          'Chile',      'Venezuela',        'Nigeria',
#         'Morocco',          'Kenya']
# Length: 50, dtype: str
#
# --- Year range ---
# From 2000 to 2026

# %%
# Explore Energy Mix


print("=" * 50)
print("ENERGY MIX DATASET")
print("=" * 50)

print("\n--- First 5 rows ---")
print(energy_mix.head())

print("\n--- Column Info ---")
print(energy_mix.info())

print("\n--- Statistics ---")
print(energy_mix.describe())
# Out:
# ==================================================
# ENERGY MIX DATASET
# ==================================================
#
# --- First 5 rows ---
#    year country iso3 region  coal_pct  oil_pct  gas_pct  nuclear_pct  \
# 0  2000   China  CHN   Asia     68.00    21.98     2.78         0.87
# 1  2001   China  CHN   Asia     67.64    21.35     3.36         0.97
# 2  2002   China  CHN   Asia     67.56    21.21     3.19         1.30
# 3  2003   China  CHN   Asia     67.69    20.71     3.24         1.30
# 4  2004   China  CHN   Asia     67.76    20.44     3.48         1.02
#
#    hydro_pct  solar_pct  wind_pct  other_renewables_pct  renewables_total_pct  \
# 0       6.36       0.01      0.00                  0.00                  6.37
# 1       6.46       0.00      0.04                  0.17                  6.68
# 2       6.38       0.00      0.35                  0.03                  6.76
# 3       6.33       0.07      0.33                  0.34                  7.06
# 4       6.57       0.02      0.20                  0.50                  7.29
#
#    fossil_total_pct
# 0             92.75
# 1             92.36
# 2             91.95
# 3             91.64
# 4             91.68
#
# --- Column Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  1350 non-null   int64
#  1   country               1350 non-null   str
#  2   iso3                  1350 non-null   str
#  3   region                1350 non-null   str
#  4   coal_pct              1350 non-null   float64
#  5   oil_pct               1350 non-null   float64
#  6   gas_pct               1350 non-null   float64
#  7   nuclear_pct           1350 non-null   float64
#  8   hydro_pct             1350 non-null   float64
#  9   solar_pct             1350 non-null   float64
#  10  wind_pct              1350 non-null   float64
#  11  other_renewables_pct  1350 non-null   float64
#  12  renewables_total_pct  1350 non-null   float64
#  13  fossil_total_pct      1350 non-null   float64
# dtypes: float64(10), int64(1), str(3)
# memory usage: 147.8 KB
# None
#
# --- Statistics ---
#               year     coal_pct      oil_pct      gas_pct  nuclear_pct  \
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean   2013.000000    15.358970    36.529304    25.293719     5.157615
# std       7.791767    15.737703     7.962231    13.641831     6.444548
# min    2000.000000     0.000000    10.780000     2.640000     0.000000
# 25%    2006.000000     3.817500    32.500000    14.390000     1.150000
# 50%    2013.000000    11.865000    35.500000    24.120000     2.545000
# 75%    2020.000000    23.890000    42.912500    37.357500     8.977500
# max    2026.000000    75.450000    51.840000    56.120000    42.470000
#
#          hydro_pct    solar_pct     wind_pct  other_renewables_pct  \
# count  1350.000000  1350.000000  1350.000000           1350.000000
# mean      7.880600     2.973963     2.747970              4.057570
# std       8.437632     2.552514     2.887144              3.022374
# min       0.000000     0.000000     0.000000              0.000000
# 25%       2.100000     0.875000     0.460000              1.690000
# 50%       4.740000     2.520000     1.825000              3.860000
# 75%       9.935000     4.567500     4.130000              5.610000
# max      35.280000    18.840000    15.370000             15.190000
#
#        renewables_total_pct  fossil_total_pct
# count           1350.000000       1350.000000
# mean              17.660215         77.182059
# std               11.956569         12.704714
# min                0.670000         40.810000
# 25%                7.432500         67.642500
# 50%               15.655000         77.820000
# 75%               23.397500         89.565000
# max               51.490000         99.330000

# %%
# Explore Temperature Anomaly


print("=" * 50)
print("TEMPERATURE ANOMALY DATASET")
print("=" * 50)

print("\n--- First 5 rows ---")
print(temp_anomaly.head())

print("\n--- Column Info ---")
print(temp_anomaly.info())

print("\n--- Regions in dataset ---")
print(temp_anomaly["region"].unique())
# Out:
# ==================================================
# TEMPERATURE ANOMALY DATASET
# ==================================================
#
# --- First 5 rows ---
#   year_month  year  month               region  temp_anomaly_c  \
# 0    2000-01  2000      1               Global           0.432
# 1    2000-01  2000      1               Arctic           1.500
# 2    2000-01  2000      1  Northern_Hemisphere           0.468
# 3    2000-01  2000      1  Southern_Hemisphere           0.320
# 4    2000-01  2000      1              Tropics           0.272
#
#   temp_anomaly_baseline  co2_ppm
# 0             1951-1980   367.44
# 1             1951-1980      NaN
# 2             1951-1980      NaN
# 3             1951-1980      NaN
# 4             1951-1980      NaN
#
# --- Column Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year_month             2528 non-null   str
#  1   year                   2528 non-null   int64
#  2   month                  2528 non-null   int64
#  3   region                 2528 non-null   str
#  4   temp_anomaly_c         2528 non-null   float64
#  5   temp_anomaly_baseline  2528 non-null   str
#  6   co2_ppm                316 non-null    float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 138.4 KB
# None
#
# --- Regions in dataset ---
# <StringArray>
# [             'Global',              'Arctic', 'Northern_Hemisphere',
#  'Southern_Hemisphere',             'Tropics',       'North_America',
#               'Europe',                'Asia']
# Length: 8, dtype: str

# %%
# CELL 4C: Clean CO2 Emissions


# Check for missing values ---
print("Missing values in co2_emissions:")
print(co2_emissions.isnull().sum())

# --- Remove duplicates ---
before = len(co2_emissions)
co2_emissions = co2_emissions.drop_duplicates()
after = len(co2_emissions)
print(f"\nRemoved {before - after} duplicate rows")

# --- Make sure year is integer ---
co2_emissions["year"] = co2_emissions["year"].astype(int)

# --- Sort by country and year ---
co2_emissions = co2_emissions.sort_values(["country", "year"]).reset_index(drop=True)

print("\n CO2 emissions cleaned!")
print(co2_emissions.head())
# Out:
# Missing values in co2_emissions:
# year                            0
# country                         0
# iso3                            0
# region                          0
# co2_emissions_mt                0
# population_millions             0
# co2_per_capita_t                0
# co2_intensity_kg_per_gdp_usd    0
# dtype: int64
#
# Removed 0 duplicate rows
#
#  CO2 emissions cleaned!
#    year  country iso3 region  co2_emissions_mt  population_millions  \
# 0  2000  Algeria  DZA   MENA             102.0                 38.2
# 1  2001  Algeria  DZA   MENA             103.0                 38.6
# 2  2002  Algeria  DZA   MENA             105.4                 38.9
# 3  2003  Algeria  DZA   MENA             108.1                 39.2
# 4  2004  Algeria  DZA   MENA             111.1                 39.5
#
#    co2_per_capita_t  co2_intensity_kg_per_gdp_usd
# 0              2.67                          0.53
# 1              2.67                          0.49
# 2              2.71                          0.45
# 3              2.76                          0.42
# 4              2.82                          0.40

# %%
# CELL 4D: Clean Energy Mix


# --- Check for missing values ---
print("Missing values in energy_mix:")
print(energy_mix.isnull().sum())

# --- Fill missing percentage values with 0
# (if a country has no solar, it means 0%, not unknown)
percentage_columns = [
    "coal_pct", "oil_pct", "gas_pct", "nuclear_pct",
    "hydro_pct", "solar_pct", "wind_pct",
    "other_renewables_pct", "renewables_total_pct", "fossil_total_pct"
]
energy_mix[percentage_columns] = energy_mix[percentage_columns].fillna(0)

# --- Remove duplicates ---
before = len(energy_mix)
energy_mix = energy_mix.drop_duplicates()
after = len(energy_mix)
print(f"Removed {before - after} duplicate rows")

print("\n Energy mix cleaned!")
print(energy_mix.head())
# Out:
# Missing values in energy_mix:
# year                    0
# country                 0
# iso3                    0
# region                  0
# coal_pct                0
# oil_pct                 0
# gas_pct                 0
# nuclear_pct             0
# hydro_pct               0
# solar_pct               0
# wind_pct                0
# other_renewables_pct    0
# renewables_total_pct    0
# fossil_total_pct        0
# dtype: int64
# Removed 0 duplicate rows
#
#  Energy mix cleaned!
#    year country iso3 region  coal_pct  oil_pct  gas_pct  nuclear_pct  \
# 0  2000   China  CHN   Asia     68.00    21.98     2.78         0.87
# 1  2001   China  CHN   Asia     67.64    21.35     3.36         0.97
# 2  2002   China  CHN   Asia     67.56    21.21     3.19         1.30
# 3  2003   China  CHN   Asia     67.69    20.71     3.24         1.30
# 4  2004   China  CHN   Asia     67.76    20.44     3.48         1.02
#
#    hydro_pct  solar_pct  wind_pct  other_renewables_pct  renewables_total_pct  \
# 0       6.36       0.01      0.00                  0.00                  6.37
# 1       6.46       0.00      0.04                  0.17                  6.68
# 2       6.38       0.00      0.35                  0.03                  6.76
# 3       6.33       0.07      0.33                  0.34                  7.06
# 4       6.57       0.02      0.20                  0.50                  7.29
#
#    fossil_total_pct
# 0             92.75
# 1             92.36
# 2             91.95
# 3             91.64
# 4             91.68

# %%
# CELL 4E: Clean Temperature Anomaly


# --- Check for missing values ---
print("Missing values in temp_anomaly:")
print(temp_anomaly.isnull().sum())

# --- Fill missing co2_ppm values using forward fill ---
# Forward fill means: use the last known value to fill the gap

temp_anomaly["co2_ppm"] = temp_anomaly["co2_ppm"].ffill()

# --- Make sure year and month are integers ---
temp_anomaly["year"] = temp_anomaly["year"].astype(int)
temp_anomaly["month"] = temp_anomaly["month"].astype(int)

# --- Remove duplicates ---
before = len(temp_anomaly)

temp_anomaly = temp_anomaly.drop_duplicates()

after = len(temp_anomaly)

print(f"Removed {before - after} duplicate rows")

print("\n Temperature anomaly cleaned!")

# --- Display first rows ---
print(temp_anomaly.head())
# Out:
# Missing values in temp_anomaly:
# year_month                  0
# year                        0
# month                       0
# region                      0
# temp_anomaly_c              0
# temp_anomaly_baseline       0
# co2_ppm                  2212
# dtype: int64
# Removed 0 duplicate rows
#
#  Temperature anomaly cleaned!
#   year_month  year  month               region  temp_anomaly_c  \
# 0    2000-01  2000      1               Global           0.432
# 1    2000-01  2000      1               Arctic           1.500
# 2    2000-01  2000      1  Northern_Hemisphere           0.468
# 3    2000-01  2000      1  Southern_Hemisphere           0.320
# 4    2000-01  2000      1              Tropics           0.272
#
#   temp_anomaly_baseline  co2_ppm
# 0             1951-1980   367.44
# 1             1951-1980   367.44
# 2             1951-1980   367.44
# 3             1951-1980   367.44
# 4             1951-1980   367.44
